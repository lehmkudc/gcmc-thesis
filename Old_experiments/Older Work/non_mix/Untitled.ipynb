# %%
from random import random, seed, randrange
from math import floor, pi
import matplotlib.pyplot as plt
import numpy as np
import os
from time import time
import pandas as pd
from scipy.integrate import simps, trapz, cumtrapz
from scipy.ndimage.filters import gaussian_filter1d
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 9]

# %%
data = pd.read_csv( 'one_run20k_nok.csv' )
data['yco'] = data.rhoco/(data.rhoco+data.rhome)
data['rho'] = data.rhoco+data.rhome
data.head()
# Out:
#    Unnamed: 0     rhoco     rhome            En             P       yco  \
# 0           0  0.000800  0.001187  8.454674e+10  9.274875e+09  0.402535
# 1           1  0.000794  0.001193  8.451407e+10  9.274867e+09  0.399678
# 2           2  0.000795  0.001198  3.713573e+10  4.080983e+09  0.398793
# 3           3  0.000816  0.001200  5.619517e+05  6.262969e+04  0.404636
# 4           4  0.000827  0.001195  2.537698e+05  2.840912e+04  0.409018
#
#         rho
# 0  0.001986
# 1  0.001987
# 2  0.001993
# 3  0.002015
# 4  0.002021

# %%
plt.scatter( np.arange(20000), 'yco', data = data, alpha = 0.1)

# %%
select = data[data.P<30]
plt.scatter( np.arange( select.shape[0]), 'P', data = select, alpha = 0.1)

# %%
plt.plot( 'rho', data = data)

# %%
data = pd.read_csv( 'one_run20k_wk.csv' )
data['yco'] = data.rhoco/(data.rhoco+data.rhome)
data['rho'] = data.rhoco+data.rhome
data.head()
# Out:
#    Unnamed: 0     rhoco     rhome            En            P       yco  \
# 0           0  0.000825  0.001164  80579.493562  8909.699351  0.414967
# 1           1  0.000828  0.001161  80201.242602  8868.925203  0.416277
# 2           2  0.000838  0.001154  80094.645838  8866.492298  0.420688
# 3           3  0.000841  0.001152  64358.980925  7134.253297  0.421983
# 4           4  0.000847  0.001152  37168.970671  4142.578096  0.423673
#
#         rho
# 0  0.001989
# 1  0.001990
# 2  0.001992
# 3  0.001994
# 4  0.001998

# %%
plt.scatter( np.arange(20000), 'yco', data = data, alpha = 0.1)

# %%
select = data[data.P<30]
plt.scatter( np.arange( select.shape[0]), 'P', data = select, alpha = 0.1)

# %%
plt.plot( 'rho', data = data)

# %%
data = pd.read_csv( 'one_run20k_nomix.csv' )
data['yco'] = data.rhoco/(data.rhoco+data.rhome)
data['rho'] = data.rhoco+data.rhome
data.head()
# Out:
#    Unnamed: 0     rhoco     rhome            En             P       yco  \
# 0           0  0.000733  0.000946  2.847544e+07  2.639880e+06  0.436686
# 1           1  0.000740  0.000958  2.811404e+07  2.637206e+06  0.435660
# 2           2  0.000749  0.000966  2.781325e+07  2.634985e+06  0.436870
# 3           3  0.000761  0.000969  2.754105e+07  2.631096e+06  0.440060
# 4           4  0.000770  0.000966  2.745096e+07  2.630903e+06  0.443544
#
#         rho
# 0  0.001679
# 1  0.001698
# 2  0.001715
# 3  0.001730
# 4  0.001735

# %%
plt.scatter( np.arange(20000), 'yco', data = data, alpha = 0.1)

# %%
select = data[data.P<30]
plt.scatter( np.arange( select.shape[0]), 'P', data = select, alpha = 0.1)

# %%
plt.plot( 'rho', data = data)
