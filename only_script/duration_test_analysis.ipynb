# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import simps, trapz, cumtrapz
from scipy.ndimage.filters import gaussian_filter1d
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 9]
import os

# %%
rep0 = pd.read_csv('duration_test0.0.csv')
rep1 = pd.read_csv('duration_test1.0.csv')
rep2 = pd.read_csv('duration_test2.0.csv')
rep0.head()
# Out:
#      rhocov  rhomev         Env        Pv     Ncov  Nmev
# 0  0.000490     0.0  -34.589318  2.146119   91.374   0.0
# 1  0.001196     0.0  -82.354534  3.980477  223.293   0.0
# 2  0.001591     0.0 -123.766739  4.196732  297.003   0.0
# 3  0.001783     0.0 -140.842237  5.380630  332.882   0.0
# 4  0.001998     0.0 -158.162541  6.766992  372.929   0.0

# %%
plt.plot(rep0.Pv)
plt.plot(rep1.Pv)
plt.plot(rep2.Pv)

# %%
plt.plot(rep0.Env)
plt.plot(rep1.Env)
plt.plot(rep2.Env)

# %%
plt.plot(rep0.Ncov)
plt.plot(rep1.Ncov)
plt.plot(rep2.Ncov)
