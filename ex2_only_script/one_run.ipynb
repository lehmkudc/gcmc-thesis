# %%
from random import random, seed, randrange
from math import floor, pi
import numpy as np
import os
from time import time
import pandas as pd
from time import time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import simps, trapz, cumtrapz
from scipy.ndimage.filters import gaussian_filter1d
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 9]
import os

# %%
# %run -i "gcmc.py"

# %%
yco = 1
P_res = 200*10**5 #[Pa]
T = 30 + 273.15 #K
fco, fme = PR_Fugacity( P_res/10**5, T, yco )
fco = fco*10**5
fme = fme*10**5

del_sf = "Nothing"#3.35 #[A]
rho_sf = "Nothing"#0.114 #[A^-3]
W = "Nothing"#5*3.8 #[A] relative to diameter of methane 3.80A
sf = False
mega_verbose = False

s_box = 45
N_max = 50000
Vol = s_box**3
kb = 1.3806*10**(7) #[Pa*A^3/K]
Nco = 0 #floor(fco*Vol/kb/T)
Nme = 0 #floor(fme*Vol/kb/T)
Nc = 0
rc = s_box
beta = 1/T
zz_co = beta*fco
zz_me = beta*fme
delta = 1
pi_move = 0.5

N_moves = 1000
N_equil = 0
N_prod = int( np.round( 2000000/N_moves) )


rhocov,rhomev,Env,Pv,Ncov, Nmev = mc_run(verbose = True)
# Out:
# 0 yco:  1.0 N:  66 P:  32.21 En:  -46.41 Accept%: 0.963 0.918 0.348

# %%
plt.plot( Env)

# %%
plt.plot( Pv )
plt.hlines( y = 20, xmin = 0, xmax = 2000)

# %%
plt.plot( rhocov )
z = PR_Zmix(200, T, 1)
rho = 200*10**5/z/kb/T
plt.hlines( y = rho, xmin = 0, xmax = 2000)
